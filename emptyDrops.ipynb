# %%
import scanpy as sc
import numpy as np
import anndata as ad
from scipy.special import gammaln, factorial, loggamma
from statsmodels.stats.multitest import multipletests
from concurrent.futures import ProcessPoolExecutor

# %%
raw_h5_path = '../01_Daten/raw_feature_bc_matrix.h5'
raw_adata = sc.read_10x_h5(raw_h5_path, gex_only=True)
# Out:
# /opt/anaconda3/envs/BIH_first-env/lib/python3.12/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/anaconda3/envs/BIH_first-env/lib/python3.12/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
def empty_drops(m, lower=100, retain=None, barcode_args: list = None, round_data=True, test_ambient=False, BPPARAM=None):
    if BPPARAM is None:
        BPPARAM = ProcessPoolExecutor()

    if test_ambient is None:
        correct_ambient = test_ambient #check if really needed
        test_ambient = True
        
    m = np.copy(m) #check if copy is needed and if aufwand is too much. had fear of changing the reference matrix
    
    if round_data:
        m = np.round(m).astype(int)
        
    #stats = test_empty_drops(m, lower=lower, round_data=False, test_ambient=test_ambient, BPPARAM=BPPARAM)

# %%
empty_drops(raw_adata)
# Out:
# KeyboardInterrupt
